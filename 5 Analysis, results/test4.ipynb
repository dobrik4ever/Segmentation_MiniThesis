# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../4 Raw data/good stacks/160719_06 stack_16-03-20/Statistics for Classified image_processed.csv')
# df['Volume um'] = df['Volume (^3)']
df
# Out:
#      Volume (pixel^3)  Surface (pixel^2)  Nb of obj. voxels  \
# 0                  45                118                 45
# 1                1715               1314               1715
# 2                 835                834                835
# 3                 746                698                746
# 4                 468                540                468
# ..                ...                ...                ...
# 858               463                542                463
# 859               326                382                326
# 860               271                312                271
# 861               334                482                334
# 862               340                474                340
#
#      Nb of surf. voxels  IntDen   Mean  StdDev  Median  Min  Max  ...  \
# 0                    43      45    1.0     0.0       1    1    1  ...
# 1                   748  406455  237.0     0.0     237  237  237  ...
# 2                   430   74315   89.0     0.0      89   89   89  ...
# 3                   370   97726  131.0     0.0     131  131  131  ...
# 4                   336   71136  152.0     0.0     152  152  152  ...
# ..                  ...     ...    ...     ...     ...  ...  ...  ...
# 858                 349  400032  864.0     0.0     864  864  864  ...
# 859                 253  285250  875.0     0.0     875  875  875  ...
# 860                 209  238751  881.0     0.0     881  881  881  ...
# 861                 334  290914  871.0     0.0     871  871  871  ...
# 862                 340  297840  876.0     0.0     876  876  876  ...
#
#      Median dist. to surf. (pixel)       XM       YM      ZM   BX   BY  BZ  \
# 0                            1.914  196.133    1.156   1.978  193    0   1
# 1                            7.653  223.493    2.557  12.029  216    0   1
# 2                            5.955  240.268    2.891   6.257  233    0   1
# 3                            5.273  283.237    3.208   7.819  279    0   1
# 4                            5.283  301.034    1.190   7.959  293    0   1
# ..                             ...      ...      ...     ...  ...  ...  ..
# 858                          5.267  279.836  280.927  65.978  271  273  65
# 859                          4.573  214.273  401.460  65.985  210  394  65
# 860                          4.154  123.011  469.561  65.989  118  465  65
# 861                          5.214  312.872  325.159  66.497  305  318  66
# 862                          5.254   88.209  402.812  66.497   81  395  66
#
#      B-width  B-height  B-depth
# 0          7         5        4
# 1         17         9       27
# 2         18         9       13
# 3          9        10       19
# 4         16         4       14
# ..       ...       ...      ...
# 858       17        15        3
# 859       11        14        3
# 860       11        10        3
# 861       18        14        2
# 862       15        17        2
#
# [863 rows x 25 columns]

# %%
df['Volume (pixel^3)'].hist(bins=100, figsize=(20,20));
